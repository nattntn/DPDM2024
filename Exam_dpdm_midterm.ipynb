# %% [markdown]
# <a href="https://colab.research.google.com/github/nattntn/DPDM2024/blob/main/Exam_dpdm_midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ข้อสอบกลางภาค ข้อที่ 1
#
# นางสาวณัฐนิช หิรัญชวโรจน์ 675020011-0

# %% [markdown]
# เบาะแส
#
#
# ให้สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) **ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City** โดยเริ่มจากการตรวจสอบ ข้อมูลคดี (crime_scene_report.csv)

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %% [markdown]
# # 1 data explore

# %% [markdown]
# ## crime_scene_report.csv ข้อมูลคดี

# %%
crime_scene = pd.read_csv('/content/gdrive/MyDrive/Exam_2/crime_scene_report.csv')
crime_scene
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
crime_scene.isnull().any()
# Out:
# date           False
# type           False
# description    False
# city           False
# dtype: bool

# %%
crime_scene.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1228 entries, 0 to 1227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1228 non-null   int64
#  1   type         1228 non-null   object
#  2   description  1228 non-null   object
#  3   city         1228 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 38.5+ KB

# %%
crime_scene['type'].unique()
# Out:
# array(['robbery', 'murder', 'theft', 'fraud', 'arson', 'bribery',
#        'assault', 'smuggling', 'blackmail'], dtype=object)

# %%
print(f"data start date: {crime_scene['date'].min()}")
print(f"data end date: {crime_scene['date'].max()}")
# Out:
# data start date: 20170101
# data end date: 20180501

# %%
crime_scene.groupby('type').count()
# Out:
#            date  description  city
# type
# arson       148          148   148
# assault     145          145   145
# blackmail   130          130   130
# bribery     135          135   135
# fraud       130          130   130
# murder      148          148   148
# robbery     134          134   134
# smuggling   117          117   117
# theft       141          141   141

# %%
city_s = crime_scene[crime_scene['city'].str.startswith(('S', 's'))]

# %%
city_s['city'].unique()
# Out:
# array(['SQL City', 'Seattle', 'Seaside', 'Savannah', 'Springdale',
#        'San Bernardino', 'Sterling Heights', 'Santa Clarita',
#        'Saint Louis', 'Scranton', 'Salinas', 'Scottsdale', 'Saint Paul',
#        'San Francisco', 'Salem', 'Santa Cruz', 'Syracuse', 'Santa Rosa',
#        'San Antonio', 'San Buenaventura', 'Santa Clara',
#        'Saint Petersburg', 'Springfield', 'South Lyon', 'Sarasota',
#        'Sioux Falls', 'St. Petersburg', 'St. Paul', 'Saginaw',
#        'Santa Ana', 'Shreveport', 'Salt Lake City', 'St. Louis',
#        'Santa Maria', 'Sioux City', 'South Bend', 'Stockton', 'San Jose',
#        'Sacramento', 'Sunnyvale', 'Spokane', 'Stamford', 'San Diego',
#        'Spartanburg'], dtype=object)

# %% [markdown]
# ## person.csv ข้อมูลประชากร

# %%
person = pd.read_csv('/content/gdrive/MyDrive/Exam_2/person.csv')
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
person.isnull().any()
# Out:
# id                     False
# name                   False
# license_id             False
# address_number         False
# address_street_name    False
# ssn                    False
# dtype: bool

# %%
person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10011 entries, 0 to 10010
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10011 non-null  int64
#  1   name                 10011 non-null  object
#  2   license_id           10011 non-null  int64
#  3   address_number       10011 non-null  int64
#  4   address_street_name  10011 non-null  object
#  5   ssn                  10011 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 469.4+ KB

# %%
print(f"unique ID:{len(person['id'].unique())}")
print(f"unique name:{len(person['name'].unique())}")
print(f"unique license:{len(person['license_id'].unique())}")
# Out:
# unique ID:10011
# unique name:10011
# unique license:10011

# %% [markdown]
# ## interview.csv ข้อมูลการสอบสวน

# %%
interview = pd.read_csv('/content/gdrive/MyDrive/Exam_2/interview.csv')
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
interview.isnull().any()
# Out:
# person_id     False
# transcript    False
# dtype: bool

# %%
interview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   person_id   4991 non-null   int64
#  1   transcript  4991 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 78.1+ KB

# %%
print(f"unique person_id:{len(interview['person_id'].unique())}")
# Out:
# unique person_id:4991

# %% [markdown]
# ## income.csv ข้อมูลรายได้

# %%
income = pd.read_csv('/content/gdrive/MyDrive/Exam_2/income.csv')
income
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
income.isnull().any()
# Out:
# ssn              False
# annual_income    False
# dtype: bool

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7514 entries, 0 to 7513
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ssn            7514 non-null   int64
#  1   annual_income  7514 non-null   int64
# dtypes: int64(2)
# memory usage: 117.5 KB

# %%
print(f"unique ssn:{len(income['ssn'].unique())}")
# Out:
# unique ssn:7514

# %% [markdown]
# ## get_fit_now_member.csv ข้อมูลสมาชิก

# %%
member_fit = pd.read_csv('/content/gdrive/MyDrive/Exam_2/get_fit_now_member.csv')
member_fit
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
member_fit.isnull().any()
# Out:
# id                       False
# person_id                False
# name                     False
# membership_start_date    False
# membership_status        False
# dtype: bool

# %%
member_fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     184 non-null    object
#  1   person_id              184 non-null    int64
#  2   name                   184 non-null    object
#  3   membership_start_date  184 non-null    int64
#  4   membership_status      184 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.3+ KB

# %%
print(f"unique ID:{len(member_fit['id'].unique())}")
print(f"unique name:{len(member_fit['person_id'].unique())}")
print(f"unique license:{len(member_fit['name'].unique())}")
# Out:
# unique ID:184
# unique name:184
# unique license:184

# %% [markdown]
# ## get_fit_now_check_in.csv ข้อมูลการเข้าใช้ ฟิตเนส Get Fit Now

# %%
time_checkin_fit = pd.read_csv('/content/gdrive/MyDrive/Exam_2/get_fit_now_check_in.csv')
time_checkin_fit
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
time_checkin_fit.isnull().any()
# Out:
# membership_id     False
# check_in_date     False
# check_in_time     False
# check_out_time    False
# dtype: bool

# %%
time_checkin_fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2703 entries, 0 to 2702
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   membership_id   2703 non-null   object
#  1   check_in_date   2703 non-null   int64
#  2   check_in_time   2703 non-null   int64
#  3   check_out_time  2703 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 84.6+ KB

# %%
print(f"unique membership_id:{len(time_checkin_fit['membership_id'].unique())}")
# Out:
# unique membership_id:184

# %% [markdown]
# ## facebook_event_checkin.csv ข้อมูลการเช็คอิน Facebook

# %%
facebook= pd.read_csv('/content/gdrive/MyDrive/Exam_2/facebook_event_checkin.csv')
facebook
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
facebook.isnull().any()
# Out:
# person_id     False
# event_id      False
# event_name    False
# date          False
# dtype: bool

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20011 entries, 0 to 20010
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   person_id   20011 non-null  int64
#  1   event_id    20011 non-null  int64
#  2   event_name  20011 non-null  object
#  3   date        20011 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 625.5+ KB

# %%
print(f"unique person_id:{len(facebook['person_id'].unique())}")
print(f"unique event_id:{len(facebook['event_id'].unique())}")
print(f"unique event_name:{len(facebook['event_name'].unique())}")
# Out:
# unique person_id:10003
# unique event_id:1001
# unique event_name:967

# %% [markdown]
# ## driver_license.csv ข้อมูลใบขับขี่

# %%
driver= pd.read_csv('/content/gdrive/MyDrive/Exam_2/drivers_license.csv')
driver
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
driver.isnull().any()
# Out:
# id              False
# age             False
# height          False
# eye_color       False
# hair_color      False
# gender          False
# plate_number    False
# car_make        False
# car_model       False
# dtype: bool

# %%
driver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10007 entries, 0 to 10006
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10007 non-null  int64
#  1   age           10007 non-null  int64
#  2   height        10007 non-null  int64
#  3   eye_color     10007 non-null  object
#  4   hair_color    10007 non-null  object
#  5   gender        10007 non-null  object
#  6   plate_number  10007 non-null  object
#  7   car_make      10007 non-null  object
#  8   car_model     10007 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 703.7+ KB

# %%
print(f"unique id:{len(driver['id'].unique())}")
print(f"unique plate_number:{len(driver['plate_number'].unique())}")
# Out:
# unique id:10007
# unique plate_number:10007

# %% [markdown]
# # เริ่มสืบ

# %% [markdown]
# ## เบาะแสที่ 1
#
# คดีนี้เป็นคดี ฆาตรกรรม (murder) **ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City**

# %%
crime_scene
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
crime_scene[crime_scene['city'] == 'SQL City'] #คดีทั้งหมดที่เกิดในเมือง SQL City
# Out:
#           date     type                                        description  \
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# 7     20170712    theft  A lone hunter stalks the night, firing arrows ...
# 8     20170820    arson  Wield the Hammer of Sol with honor, Titan, it ...
# 9     20171110  robbery  The Gjallarhorn shoulder-mounted rocket system...
# 10    20180103  bribery  Apparently, Cayde thought it necessary to expo...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#           city
# 3     SQL City
# 4     SQL City
# 7     SQL City
# 8     SQL City
# 9     SQL City
# 10    SQL City
# 11    SQL City
# 12    SQL City
# 1227  SQL City

# %%
crime_scene[(crime_scene['type'] == 'murder') & (crime_scene['city'] == 'SQL City') ] #คดีที่เกิดขึ้นในเมือง SQL City และเป็นคดี ฆาตรกรรม
# Out:
#           date    type                                        description  \
# 3     20180215  murder                         REDACTED REDACTED REDACTED
# 4     20180215  murder  Someone killed the guard! He took an arrow to ...
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 3     SQL City
# 4     SQL City
# 1227  SQL City

# %%
# ทำการเรียกดูข้อมูล ใน crime_scene_report ในคดีประเภท murder ที่เกิดขึ้น ณ เมือง SQL City วันที่ 15/01/2018
scene_focus = crime_scene[(crime_scene['type'] == 'murder') & (crime_scene['city'] == 'SQL City') & (crime_scene['date'] == 20180115)]
scene_focus
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %%
for i in scene_focus['description'].tolist():
    print(i)
    for sentence in i.split('.'):
        print(sentence.strip())  # ใช้ strip() เพื่อลบช่องว่างส่วนเกิน
# Out:
# Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# Security footage shows that there were 2 witnesses
# The first witness lives at the last house on "Northwestern Dr"
# The second witness, named Annabel, lives somewhere on "Franklin Ave"

# %% [markdown]
# ## เบาะแสที่ 2
#
# from Security footage we have 2 witnesses
#
# The first witness lives at the last house on "Northwestern Dr
#
# and
#
# The second witness, named Annabel, lives somewhere on "Franklin Ave

# %% [markdown]
# ### Find the first witness

# %%
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
person[person['address_street_name'] == 'Northwestern Dr']
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %%
# person[person['address_street_name'] == 'Northwestern Dr'].sort_values(by='address_number', ascending=False)

# %%
# data of person who live in Northwestern Dr street
North_address = person[person['address_street_name'] == 'Northwestern Dr']
print(North_address.shape)
North_address.head()
# Out:
# (50, 6)
#         id            name  license_id  address_number address_street_name  \
# 2    10010       Muoi Cary      385336             741     Northwestern Dr
# 282  12711  Norman Apolito      667757             599     Northwestern Dr
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 528  15171    Weldon Penso      336999             311     Northwestern Dr
# 811  17729  Lasonya Wildey      439686            3824     Northwestern Dr
#
#            ssn
# 2    828638512
# 282  778264744
# 499  111564949
# 528  131379495
# 811  917817122

# %%
maximum = 0
for number in North_address['address_number'].tolist():
    if maximum < number:
       maximum = number
print(maximum)

first_witness_info = North_address[North_address['address_number'] == maximum]
first_witness_info
# Out:
# 4919
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %% [markdown]
# #### First witness

# %%
print(f"first_witness ID: {first_witness_info['id'].values[0]}")
print(f"first_witness name: {first_witness_info['name'].values[0]}")
print(f"first_witness address_number: {first_witness_info['address_number'].values[0]}")
print(f"first_witness address_street_name: {first_witness_info['address_street_name'].values[0]}")
print(f"first_witness license_id: {first_witness_info['license_id'].values[0]}")
print(f"first_witness ssn: {first_witness_info['ssn'].values[0]}")
# Out:
# first_witness ID: 14887
# first_witness name: Morty Schapiro
# first_witness address_number: 4919
# first_witness address_street_name: Northwestern Dr
# first_witness license_id: 118009
# first_witness ssn: 111564949

# %% [markdown]
# ### Find the second witness

# %%
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
person[person['name'].str.startswith('Annabel')]
# Out:
#          id                name  license_id  address_number  \
# 665   16371      Annabel Miller      490173             103
# 7601  78354      Annabell Siona      158932             978
# 7650  78799  Annabell Droneburg      984316            1944
# 8509  86541   Annabell Zwilling      709133            1859
#
#      address_street_name        ssn
# 665         Franklin Ave  318771143
# 7601       Whitewater Dr  800278294
# 7650        W Natalie Dr  478793500
# 8509            Patti Rd  332961158

# %%
person[person['address_street_name'] == 'Franklin Ave']
# Out:
#          id                 name  license_id  address_number  \
# 235   12207       Wilmer Wolever      509484             139
# 665   16371       Annabel Miller      490173             103
# 807   17683        Johnnie Schee      968887            1277
# 936   18651        Carleen Etoll      356746              22
# 1377  22636       Zachary Ybarbo      768359             785
# 1608  24737           Gema Nantz      273410            3968
# 2236  30654      Clarita Rickels      418084            2254
# 2427  32264       Shelby Dezeeuw      735415            1391
# 2584  33793         Amado Mattan      161915              99
# 2661  34592    Cordell Lindamood      592762            3657
# 2864  36328         Domenic Laun      971080            3809
# 2877  36400         Noe Pancoast      895755            3443
# 3009  37616     Katelyn Schwerin      430143             332
# 4086  46827         Bev Billiter      643591            2316
# ...

# %%
# find the people who name named Annabel and lives somewhere on "Franklin Ave
second_witness_info = person[(person['name'].str.startswith('Annabel')) & (person['address_street_name'] == 'Franklin Ave')]
second_witness_info
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %% [markdown]
# #### Second witness

# %%
print(f"second_witness ID: {second_witness_info['id'].values[0]}")
print(f"second_witness name: {second_witness_info['name'].values[0]}")
print(f"second_witness address_number: {second_witness_info['address_number'].values[0]}")
print(f"second_witness address_street_name: {second_witness_info['address_street_name'].values[0]}")
print(f"second_witness license_id: {second_witness_info['license_id'].values[0]}")
print(f"second_witness ssn: {second_witness_info['ssn'].values[0]}")
# Out:
# second_witness ID: 16371
# second_witness name: Annabel Miller
# second_witness address_number: 103
# second_witness address_street_name: Franklin Ave
# second_witness license_id: 490173
# second_witness ssn: 318771143

# %% [markdown]
# ### สืบสวนพยาน
#
# now, we know who the 2 witnesses in this crime are. then, it's time to check the interview report!
#
# this are they information

# %%
witness_info = pd.concat([first_witness_info,second_witness_info])
witness_info
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 499  111564949
# 665  318771143

# %%
# this is the information
print('---'*10,'first witness','---'*10)
print(f"first_witness ID: {witness_info['id'].values[0]}")
print(f"first_witness name: {witness_info['name'].values[0]}")
print(f"first_witness address_number: {witness_info['address_number'].values[0]}")
print(f"first_witness address_street_name: {witness_info['address_street_name'].values[0]}")
print(f"first_witness license_id: {witness_info['license_id'].values[0]}")
print(f"first_witness ssn: {witness_info['ssn'].values[0]}")
print('---'*50)
print('---'*10,'second witness','---'*10)
print(f"second_witness ID: {witness_info['id'].values[1]}")
print(f"second_witness name: {witness_info['name'].values[1]}")
print(f"second_witness address_number: {witness_info['address_number'].values[1]}")
print(f"second_witness address_street_name: {witness_info['address_street_name'].values[1]}")
print(f"second_witness license_id: {witness_info['license_id'].values[1]}")
print(f"second_witness ssn: {witness_info['ssn'].values[1]}")
print('---'*50)
# Out:
# ------------------------------ first witness ------------------------------
# first_witness ID: 14887
# first_witness name: Morty Schapiro
# first_witness address_number: 4919
# first_witness address_street_name: Northwestern Dr
# first_witness license_id: 118009
# first_witness ssn: 111564949
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------ second witness ------------------------------
# second_witness ID: 16371
# second_witness name: Annabel Miller
# second_witness address_number: 103
# second_witness address_street_name: Franklin Ave
# second_witness license_id: 490173
# second_witness ssn: 318771143
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
interview_wit = interview[(interview['person_id'] == witness_info['id'].values[0])
                        | (interview['person_id'] == witness_info['id'].values[1])]
interview_wit
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
interview_wit.drop_duplicates(subset=['person_id']) #drop อันซ้ำออกกก่อน
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
#คีย์หลักซ้ำได้ คีย์รองซ้ำไม่ได้
interview_nodup = interview_wit.drop_duplicates(subset=['person_id']) #drop อันซ้ำออกกก่อน
witness_info['transcript'] = witness_info['id'].map(interview_nodup.set_index('person_id')['transcript'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit

# %%
witness_info
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn                                         transcript
# 499  111564949  I heard a gunshot and then saw a man run out. ...
# 665  318771143  I saw the murder happen, and I recognized the ...

# %%
for id in witness_info['id'].tolist():
    print(f'person_id: {id}')
    transcript = witness_info[witness_info['id'] == id]['transcript'].values[0]
    print(transcript)
    for sentence in transcript.split('.'):
        print(sentence.strip())
# Out:
# person_id: 14887
# I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# I heard a gunshot and then saw a man run out
# He had a "Get Fit Now Gym" bag
# The membership number on the bag started with "48Z"
# Only gold members have those bags
# The man got into a car with a plate that included "H42W"
#
# person_id: 16371
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th

# %% [markdown]
# ## เบาะแสที่ 3

# %%
for id in witness_info['id'].tolist():
    print(f'person_id: {id}')
    transcript = witness_info[witness_info['id'] == id]['transcript'].values[0]
    print(transcript)
    for sentence in transcript.split('.'):
        print(sentence.strip())
# Out:
# person_id: 14887
# I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# I heard a gunshot and then saw a man run out
# He had a "Get Fit Now Gym" bag
# The membership number on the bag started with "48Z"
# Only gold members have those bags
# The man got into a car with a plate that included "H42W"
#
# person_id: 16371
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th

# %%
# ฆาตกรมาใช้บริการ ยิม ในวันที่  9 เดือนมกราคม (last week --> year 2018 ) เหตุการณ์เกิด 15/01/2018
suspects_time_fit  = time_checkin_fit[time_checkin_fit['check_in_date'] == 20180109]
print(suspects_time_fit.shape)
suspects_time_fit
# Out:
# (10, 4)
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %%
# He had a "Get Fit Now Gym" bag The membership number on the bag started with "48Z" only gold members have those bags
suspects_member_fit =  member_fit[(member_fit['id'].str.startswith('48Z')) & (member_fit['membership_status'] == 'gold')]
suspects_member_fit
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
suspects_gym = suspects_member_fit.merge(suspects_time_fit, left_on='id', right_on='membership_id')

# %%
suspects_gym = suspects_gym.drop(columns=['id'])
suspects_gym
# Out:
#    person_id           name  membership_start_date membership_status  \
# 0      28819   Joe Germuska               20160305              gold
# 1      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
# The man got into a car with a plate that included "H42W"
suspects_driver =  driver[driver['plate_number'].str.contains("H42W")] #id = license_id
suspects_driver
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
suspects_driver = suspects_driver[suspects_driver['gender']=='male']

# %%
# หาคนที่ id in  suspects_driver df = license_id in person df เพื่อหา person_id
#คีย์หลักซ้ำได้ คีย์รองซ้ำไม่ได้
person_nodup = person.drop_duplicates(subset=['license_id']) #drop อันซ้ำออกกก่อน
suspects_driver['person_id'] = suspects_driver['id'].map(person_nodup.set_index('license_id')['id'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit
# Out:
# <ipython-input-70-c0e3a0ef4d78>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   suspects_driver['person_id'] = suspects_driver['id'].map(person_nodup.set_index('license_id')['id'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit

# %%
#คีย์หลักซ้ำได้ คีย์รองซ้ำไม่ได้
suspects_driver['name'] = suspects_driver['id'].map(person_nodup.set_index('license_id')['name'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit
# Out:
# <ipython-input-71-5854e19a3c73>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   suspects_driver['name'] = suspects_driver['id'].map(person_nodup.set_index('license_id')['name'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit

# %%
suspects_driver
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 6240  664760   21      71     black      black   male       4H42WR     Nissan
#
#      car_model  person_id            name
# 3529  Spark LS      67318   Jeremy Bowers
# 6240    Altima      51739  Tushar Chandra

# %%
suspects_gym
# Out:
#    person_id           name  membership_start_date membership_status  \
# 0      28819   Joe Germuska               20160305              gold
# 1      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
suspect = suspects_gym.merge(suspects_driver, left_on='person_id', right_on='person_id')
suspect
# Out:
#    person_id         name_x  membership_start_date membership_status  \
# 0      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time      id  age  \
# 0         48Z55       20180109           1530            1700  423327   30
#
#    height eye_color hair_color gender plate_number   car_make car_model  \
# 0      70     brown      brown   male       0H42W2  Chevrolet  Spark LS
#
#           name_y
# 0  Jeremy Bowers

# %%
suspect = suspect.drop(columns=['name_y'])

# %%
suspect.rename(columns={'name_x': 'name'}, inplace=True)

# %%
suspect
# Out:
#    person_id           name  membership_start_date membership_status  \
# 0      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time      id  age  \
# 0         48Z55       20180109           1530            1700  423327   30
#
#    height eye_color hair_color gender plate_number   car_make car_model
# 0      70     brown      brown   male       0H42W2  Chevrolet  Spark LS

# %% [markdown]
# ## Jeremy Bowers	--> สอบสวนผู้ต้องสงสัย

# %%
print(f"The suspect is {suspect['name'].values[0]}.\n"
      f"He is {suspect['age'].values[0]} years old, has {suspect['hair_color'].values[0]} hair, {suspect['eye_color'].values[0]} eyes, "
      f"and stands {suspect['height'].values[0]} inches tall.\n"
      f"His car is a {suspect['car_make'].values[0]} {suspect['car_model'].values[0]} with the plate number {suspect['plate_number'].values[0]}.\n"
      f"His membership ID is {suspect['membership_id'].values[0]} with membership status {suspect['membership_status'].values[0]}.")
# Out:
# The suspect is Jeremy Bowers.
# He is 30 years old, has brown hair, brown eyes, and stands 70 inches tall.
# His car is a Chevrolet Spark LS with the plate number 0H42W2.
# His membership ID is 48Z55 with membership status gold.

# %%
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
interview_Bowers =  interview[interview['person_id']==suspect['person_id'].values[0]]
interview_Bowers
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
for i in interview_Bowers['transcript'].tolist():
    print(i)
    for sentence in i.split('.'):
        print(sentence.strip())  # ใช้ strip() เพื่อลบช่องว่างส่วนเกิน
# Out:
# I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.
#
# I was hired by a woman with a lot of money
# I don't know her name but I know she's around 5'5" (65") or 5'7" (67")
# She has red hair and she drives a Tesla Model S
# I know that she attended the SQL Symphony Concert 3 times in December 2017

# %% [markdown]
# # หาฆาตกร

# %%
driver
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
# She has red hair and she drives a Tesla Model S
driver_Tesla_S = driver[(driver['car_make'] == 'Tesla') & (driver['car_model'] == 'Model S')
                 & (driver['gender'] == 'female')& (driver['hair_color'] == 'red')]
driver_Tesla_S
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %%
# หาคนที่ id in  suspects_driver df = license_id in person df เพื่อหา person_id
#คีย์หลักซ้ำได้ คีย์รองซ้ำไม่ได้
person_nodup = person.drop_duplicates(subset=['license_id']) #drop อันซ้ำออกกก่อน
driver_Tesla_S['person_id'] = driver_Tesla_S['id'].map(person_nodup.set_index('license_id')['id'])
driver_Tesla_S['name'] = driver_Tesla_S['id'].map(person_nodup.set_index('license_id')['name'])
driver_Tesla_S['ssn'] = driver_Tesla_S['id'].map(person_nodup.set_index('license_id')['ssn'])
# Out:
# <ipython-input-84-db4963b2d4b6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_Tesla_S['person_id'] = driver_Tesla_S['id'].map(person_nodup.set_index('license_id')['id'])
# <ipython-input-84-db4963b2d4b6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_Tesla_S['name'] = driver_Tesla_S['id'].map(person_nodup.set_index('license_id')['name'])
# <ipython-input-84-db4963b2d4b6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
driver_Tesla_S
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model  person_id              name        ssn
# 1105   Model S      99716  Miranda Priestly  987756388
# 2054   Model S      90700     Regina George  337169072
# 9078   Model S      78881          Red Korb  961388910

# %%
facebook
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
#I know that she attended the SQL Symphony Concert 3 times in December 2017
SQL_event = facebook[facebook['event_name'] == 'SQL Symphony Concert']
SQL_event
# Out:
#        person_id  event_id            event_name      date
# 11         97207      1143  SQL Symphony Concert  20170322
# 12         97207      1143  SQL Symphony Concert  20180226
# 109        92433      1143  SQL Symphony Concert  20170821
# 110        92433      1143  SQL Symphony Concert  20180327
# 296        88952      1143  SQL Symphony Concert  20170918
# ...          ...       ...                   ...       ...
# 20003      24556      1143  SQL Symphony Concert  20171224
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229
# 20010      67318      1143  SQL Symphony Concert  20171206
#
# [212 rows x 4 columns]

# %%
event  = SQL_event[SQL_event['date'].astype(str).str.contains('201712')]
event
# Out:
#        person_id  event_id            event_name      date
# 4087       62596      1143  SQL Symphony Concert  20171225
# 4392       19260      1143  SQL Symphony Concert  20171214
# 6552       58898      1143  SQL Symphony Concert  20171220
# 6620       69699      1143  SQL Symphony Concert  20171214
# 6717       19292      1143  SQL Symphony Concert  20171213
# 7266       43366      1143  SQL Symphony Concert  20171207
# 8395       92343      1143  SQL Symphony Concert  20171212
# 10909      28582      1143  SQL Symphony Concert  20171220
# 10910      28582      1143  SQL Symphony Concert  20171215
# 13719      81526      1143  SQL Symphony Concert  20171202
# 13745      24397      1143  SQL Symphony Concert  20171208
# 14312      11173      1143  SQL Symphony Concert  20171223
# 15305      79312      1143  SQL Symphony Concert  20171203
# 15896      69325      1143  SQL Symphony Concert  20171206
# 20001      24556      1143  SQL Symphony Concert  20171207
# ...

# %%
counts = event['person_id'].value_counts()
counts
# Out:
# person_id
# 24556    3
# 99716    3
# 28582    2
# 62596    1
# 19260    1
# 58898    1
# 69699    1
# 19292    1
# 43366    1
# 92343    1
# 81526    1
# 24397    1
# 11173    1
# 79312    1
# 69325    1
# 67318    1
# Name: count, dtype: int64

# %%
counts[counts == 3]
# Out:
# person_id
# 24556    3
# 99716    3
# Name: count, dtype: int64

# %%
selected_id = counts[counts == 3].index
selected_id
# Out:
# Index([24556, 99716], dtype='int64', name='person_id')

# %%
driver_Tesla_S
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model  person_id              name        ssn
# 1105   Model S      99716  Miranda Priestly  987756388
# 2054   Model S      90700     Regina George  337169072
# 9078   Model S      78881          Red Korb  961388910

# %%
 suspect_2 =  driver_Tesla_S[driver_Tesla_S['person_id'].isin(selected_id)]
 suspect_2
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model  person_id              name        ssn
# 1105   Model S      99716  Miranda Priestly  987756388

# %%
income_nodup = income.drop_duplicates(subset=['ssn']) #drop อันซ้ำออกกก่อน
suspect_2['annual_income'] = suspect_2['ssn'].map(income_nodup.set_index('ssn')['annual_income'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit
# Out:
# <ipython-input-94-9d4acdaffa50>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   suspect_2['annual_income'] = suspect_2['ssn'].map(income_nodup.set_index('ssn')['annual_income'])  #เอา  price_min ของตาราง โปรเจค มาใส่ในตาราง unit

# %%
suspect_2
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model  person_id              name        ssn  annual_income
# 1105   Model S      99716  Miranda Priestly  987756388         310000

# %%
income['annual_income'].max()
# Out:
# 498500

# %%
income['annual_income'].min()
# Out:
# 10000

# %%
income['annual_income'].mean()
# Out:
# 53257.798775618845

# %%
interview[interview['person_id']==suspect_2['person_id'].values[0]]
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []

# %% [markdown]
# # ชื่่อฆาตกร

# %%
suspect_2
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
#
#      car_model  person_id              name        ssn  annual_income
# 1105   Model S      99716  Miranda Priestly  987756388         310000

# %%
print(f"The murderer is {suspect_2['name'].values[0]}.\n"
      f"She is {suspect_2['age'].values[0]} years old, has {suspect_2['hair_color'].values[0]} hair, {suspect_2['eye_color'].values[0]} eyes, "
      f"and stands {suspect_2['height'].values[0]} inches tall.\n"
      f"Her car is a {suspect_2['car_make'].values[0]} {suspect_2['car_model'].values[0]} with the plate number {suspect_2['plate_number'].values[0]}.\n"
      f"Her annual income is ${suspect_2['annual_income'].values[0]:,}.")
# Out:
# The murderer is Miranda Priestly.
# She is 68 years old, has red hair, green eyes, and stands 66 inches tall.
# Her car is a Tesla Model S with the plate number 500123.
# Her annual income is $310,000.
